# %%
# 调用numpy库生成二分类数据 40 条  没有冗余数据 ，二维数据
# def create_data():
#     import numpy as np
#     np.random.seed(0)
#     data=np.r_[np.random.randn(20,2)-[2,2],np.random.randn(20,2)+[2,2]]
#     target=20*[-1]+20*[1]

#     return data,target

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=100,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=0)
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

if __name__ == '__main__':
    data,target = create_data()
    show_data(data,target)
# Out:
# [-0.6054158   1.29670808] 1

# %%
import sklearn 

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1

# 分类效果展示
def show_data_line(data,target,w,b):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min,y_min] = np.min(data,axis=0)
    [x_max,y_max] = np.max(data,axis=0)


    XX=np.linspace(x_min-1,x_max+1)
    YY=-(w[0]/w[1])*XX-b/w[1]
    plt.plot(XX,YY,'-c',label='Hyperplane')
    plt.show()

# 初始化 w , b 
w = np.array((0.0,0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.01

while (num_epochs<=10):
    # 随机打乱数据
    data,target = sklearn.utils.shuffle(data,target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i]*(w[0]*data[i][0]+w[1]*data[i][1]+b)<=0:
            # w = w+lr*target[i]*data[i]
            w[0] = w[0]+lr*target[i]*data[i][0]
            w[1] = w[1]+lr*target[i]*data[i][1]
            b = b+lr*target[i]
        if ((i+1)%epoch == 0):
            print("第{}轮训练，第{}条数据，分类效果如图,w:{},b:{}：".format(num_epochs,(i+1),w,b))
            show_data_line(data,target,w,b)
    num_epochs+=1
# Out:
# [-0.6054158   1.29670808] 1
# 第1轮训练，第20条数据，分类效果如图,w:[-0.00073553  0.01394118],b:-0.01：
# 第1轮训练，第40条数据，分类效果如图,w:[-0.00623814  0.03695582],b:-0.01：
# 第1轮训练，第60条数据，分类效果如图,w:[-0.00640737  0.02540851],b:-0.02：
# 第1轮训练，第80条数据，分类效果如图,w:[0.00542878 0.03461623],b:-0.01：
# 第1轮训练，第100条数据，分类效果如图,w:[0.01623511 0.03379819],b:-0.019999999999999997：
# 第2轮训练，第20条数据，分类效果如图,w:[0.01623511 0.03379819],b:-0.019999999999999997：
# 第2轮训练，第40条数据，分类效果如图,w:[0.01663394 0.03711613],b:-0.009999999999999997：
# 第2轮训练，第60条数据，分类效果如图,w:[0.01997883 0.0362935 ],b:-0.009999999999999997：
# 第2轮训练，第80条数据，分类效果如图,w:[0.01000034 0.03251953],b:-0.009999999999999997：
# 第2轮训练，第100条数据，分类效果如图,w:[-0.00354866  0.03298831],b:-0.019999999999999997：
# 第3轮训练，第20条数据，分类效果如图,w:[0.00097986 0.02909693],b:-0.019999999999999997：
# 第3轮训练，第40条数据，分类效果如图,w:[-0.00106951  0.01549961],b:-0.03：
# 第3轮训练，第60条数据，分类效果如图,w:[0.01581131 0.0353456 ],b:-0.009999999999999997：
# 第3轮训练，第80条数据，分类效果如图,w:[0.0117949  0.03533335],b:-0.009999999999999997：
# 第3轮训练，第100条数据，分类效果如图,w:[-0.00175409  0.03580213],b:-0.019999999999999997：
# 第4轮训练，第20条数据，分类效果如图,w:[-0.00175409  0.03580213],b:-0.019999999999999997：
# 第4轮训练，第40条数据，分类效果如图,w:[0.00224847 0.03356099],b:-0.019999999999999997：
# 第4轮训练，第60条数据，分类效果如图,w:[0.00224847 0.03356099],b:-0.019999999999999997：
# 第4轮训练，第80条数据，分类效果如图,w:[0.00968073 0.04335565],b:-0.019999999999999997：
# 第4轮训练，第100条数据，分类效果如图,w:[0.00763136 0.02975833],b:-0.03：
# 第5轮训练，第20条数据，分类效果如图,w:[0.01432717 0.0339504 ],b:-0.03：
# 第5轮训练，第40条数据，分类效果如图,w:[0.01249821 0.04136431],b:-0.019999999999999997：
# 第5轮训练，第60条数据，分类效果如图,w:[-0.00346922  0.04108919],b:-0.03：
# 第5轮训练，第80条数据，分类效果如图,w:[0.00251548 0.04417793],b:-0.019999999999999997：
# 第5轮训练，第100条数据，分类效果如图,w:[0.01560795 0.04453109],b:-0.019999999999999997：
# 第6轮训练，第20条数据，分类效果如图,w:[0.01355858 0.03093376],b:-0.03：
# 第6轮训练，第40条数据，分类效果如图,w:[0.01671463 0.03619943],b:-0.03：
# 第6轮训练，第60条数据，分类效果如图,w:[0.02050223 0.03667947],b:-0.03：
# 第6轮训练，第80条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第6轮训练，第100条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第20条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第40条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第60条数据，分类效果如图,w:[0.00700896 0.04215097],b:-0.03：
# 第7轮训练，第80条数据，分类效果如图,w:[0.00700896 0.04215097],b:-0.03：
# 第7轮训练，第100条数据，分类效果如图,w:[-0.00044345  0.04781393],b:-0.019999999999999997：
# 第8轮训练，第20条数据，分类效果如图,w:[-0.00044345  0.04781393],b:-0.019999999999999997：
# 第8轮训练，第40条数据，分类效果如图,w:[0.0037238  0.03110513],b:-0.03：
# 第8轮训练，第60条数据，分类效果如图,w:[0.00330147 0.03894014],b:-0.03：
# 第8轮训练，第80条数据，分类效果如图,w:[0.0014725  0.04635406],b:-0.019999999999999997：
# 第8轮训练，第100条数据，分类效果如图,w:[0.0014725  0.04635406],b:-0.019999999999999997：
# 第9轮训练，第20条数据，分类效果如图,w:[-0.00134925  0.04222054],b:-0.03：
# 第9轮训练，第40条数据，分类效果如图,w:[-0.00949877  0.03103266],b:-0.04：
# 第9轮训练，第60条数据，分类效果如图,w:[0.00630061 0.03732273],b:-0.03：
# 第9轮训练，第80条数据，分类效果如图,w:[0.00164747 0.04590739],b:-0.019999999999999997：
# 第9轮训练，第100条数据，分类效果如图,w:[0.00164747 0.04590739],b:-0.019999999999999997：
# 第10轮训练，第20条数据，分类效果如图,w:[-0.00458247  0.05052995],b:-0.03：
# 第10轮训练，第40条数据，分类效果如图,w:[-0.00458247  0.05052995],b:-0.03：
# 第10轮训练，第60条数据，分类效果如图,w:[-0.012732    0.03934208],b:-0.04：
# 第10轮训练，第80条数据，分类效果如图,w:[0.00703789 0.0472006 ],b:-0.03：
# 第10轮训练，第100条数据，分类效果如图,w:[0.00703789 0.0472006 ],b:-0.03：

# %%
import numpy as np
a = np.array([1,2])
b = np.array([3,4])

print(a+b)
# Out:
# [4 6]

# %%
import sklearn 
import matplotlib.pyplot as plt
import numpy as np

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=60,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=18)
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1

# 分类效果展示
def show_data_line(data,target,w,b):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min,y_min] = np.min(data,axis=0)
    [x_max,y_max] = np.max(data,axis=0)


    XX=np.linspace(x_min-1,x_max+1)
    YY=-(w[0]/w[1])*XX-b/w[1]
    plt.plot(XX,YY,'-c',label='Hyperplane')
    plt.show()

# 优化目标： MIN L(w,b) = (-1)*yi * (w * xi + b) 最小
def loss_fun(data,target,w,b):
    loss = 0.0
    for i in range(len(target)):
        loss+= (-1)*target[i]*(np.dot(w,data[i].T)+b)
    
    return loss

# 初始化 w , b 
w = np.array((0.0,0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.005

while (num_epochs<=10):
    # 随机打乱数据
    data,target = sklearn.utils.shuffle(data,target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i]*(np.dot(w,data[i].T)+b)<=0:
            w = w+lr*target[i]*data[i]
            b = b+lr*target[i]
        if ((i+1)%epoch == 0):
            print("第{}轮训练，after第{}条数据，分类效果如图,w:{},b:{},损失函数值为{}：".format(num_epochs,(i+1),w,b,loss_fun(data,target,w,b)))
            show_data_line(data,target,w,b)
    num_epochs+=1
# Out:
# [1.32083284 1.45861278] 0
# 第1轮训练，after第20条数据，分类效果如图,w:[-0.01346245  0.00869865],b:-0.005,损失函数值为-0.7291713048939578：
# 第1轮训练，after第40条数据，分类效果如图,w:[-0.02265332  0.01322716],b:-0.005,损失函数值为-1.2180103394062338：
# 第1轮训练，after第60条数据，分类效果如图,w:[-0.02037561  0.01406459],b:-0.01,损失函数值为-1.109330345812528：
# 第2轮训练，after第20条数据，分类效果如图,w:[-0.01754476  0.01804637],b:-0.015,损失函数值为-0.9929665146523563：
# 第2轮训练，after第40条数据，分类效果如图,w:[-0.01838402  0.03091635],b:-0.009999999999999998,损失函数值为-1.1168417948866818：
# 第2轮训练，after第60条数据，分类效果如图,w:[-0.01895172  0.02307471],b:-0.015,损失函数值为-1.0953752016942973：
# 第3轮训练，after第20条数据，分类效果如图,w:[-0.020792    0.02367571],b:-0.02,损失函数值为-1.1913102176678403：
# 第3轮训练，after第40条数据，分类效果如图,w:[-0.020792    0.02367571],b:-0.02,损失函数值为-1.1913102176678403：
# 第3轮训练，after第60条数据，分类效果如图,w:[-0.02915609  0.01921004],b:-0.02,损失函数值为-1.5815524128118061：
# 第4轮训练，after第20条数据，分类效果如图,w:[-0.02915609  0.01921004],b:-0.02,损失函数值为-1.581552412811806：
# 第4轮训练，after第40条数据，分类效果如图,w:[-0.02266837  0.0310753 ],b:-0.02,损失函数值为-1.3322983169328348：
# 第4轮训练，after第60条数据，分类效果如图,w:[-0.02715385  0.01954483],b:-0.025,损失函数值为-1.4834636022383276：
# 第5轮训练，after第20条数据，分类效果如图,w:[-0.02501729  0.02360774],b:-0.025,损失函数值为-1.4023666212174568：
# 第5轮训练，after第40条数据，分类效果如图,w:[-0.02337042  0.02474716],b:-0.030000000000000002,损失函数值为-1.327183808499076：
# 第5轮训练，after第60条数据，分类效果如图,w:[-0.01951186  0.03080227],b:-0.030000000000000002,损失函数值为-1.1725683209190336：
# 第6轮训练，after第20条数据，分类效果如图,w:[-0.03196285  0.02805112],b:-0.030000000000000002,损失函数值为-1.7782791655651926：
# 第6轮训练，after第40条数据，分类效果如图,w:[-0.03423775  0.02951896],b:-0.030000000000000002,损失函数值为-1.9014822981515194：
# 第6轮训练，after第60条数据，分类效果如图,w:[-0.03179018  0.03072512],b:-0.035,损失函数值为-1.7866462450080576：
# 第7轮训练，after第20条数据，分类效果如图,w:[-0.03235789  0.02288348],b:-0.04,损失函数值为-1.7651796518156735：
# 第7轮训练，after第40条数据，分类效果如图,w:[-0.03089949  0.03205318],b:-0.04,损失函数值为-1.750512247640011：
# 第7轮训练，after第60条数据，分类效果如图,w:[-0.03718478  0.02820577],b:-0.04,损失函数值为-2.0406367538725196：
# 第8轮训练，after第20条数据，分类效果如图,w:[-0.0381466   0.03032159],b:-0.04,损失函数值为-2.1022378877130703：
# 第8轮训练，after第40条数据，分类效果如图,w:[-0.03110597  0.03872682],b:-0.04,损失函数值为-1.8032991658069428：
# 第8轮训练，after第60条数据，分类效果如图,w:[-0.03559145  0.02719635],b:-0.045,损失函数值为-1.9544644511124343：
# 第9轮训练，after第20条数据，分类效果如图,w:[-0.02933903  0.04278586],b:-0.04,损失函数值为-1.7406785170842767：
# 第9轮训练，after第40条数据，分类效果如图,w:[-0.03472942  0.03435298],b:-0.045,损失函数值为-1.9568418618413521：
# 第9轮训练，after第60条数据，分类效果如图,w:[-0.03147906  0.03307213],b:-0.049999999999999996,损失函数值为-1.7860034515787735：
# 第10轮训练，after第20条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：
# 第10轮训练，after第40条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：
# 第10轮训练，after第60条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：

# %%
1
# Out:
# 1

# %%
import sklearn 
import matplotlib.pyplot as plt

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=60,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=18)
    # random_state 取值为线性可分为  3  8 18
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1
# Out:
# [1.32083284 1.45861278] 0

# %%
import sklearn
import numpy as np

def create_data():
    """# 为了是数值取值为线性可分为 random_state 取值为 3  8 18  （后面的没有测试）  
        18 最能体现划分过程
    """
    from sklearn.datasets import make_classification
    data, target = make_classification(n_samples=60,  # 样本个数
                                       n_features=2,  # 特征个数
                                       n_informative=2,  # 有效特征个数
                                       n_redundant=0,  # 冗余特征个数（有效特征的随机组合）
                                       n_repeated=0,  # 重复特征个数（有效特征和冗余特征的随机组合）
                                       n_classes=2,  # 样本类别
                                       n_clusters_per_class=1,  # 簇的个数
                                       random_state=18)
    return data, target


# 数据的可视化
def show_data(data, target):
    import matplotlib.pyplot as plt
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if (target[i] == data_label[0]):
            plt.scatter(data[i][0], data[i][1], c='r')
        else:
            plt.scatter(data[i][0], data[i][1], c='g')
    plt.show()


data, target = create_data()
print("生成的数据如下：")
show_data(data, target)
for i in range(len(target)):
    if target[i] == 0:
        target[i] = -1


# 分类效果展示
def show_data_line(data, target, w, b):
    import matplotlib.pyplot as plt
    import numpy as np
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if (target[i] == data_label[0]):
            plt.scatter(data[i][0], data[i][1], c='r')
        else:
            plt.scatter(data[i][0], data[i][1], c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min, y_min] = np.min(data, axis=0)
    [x_max, y_max] = np.max(data, axis=0)

    XX = np.linspace(x_min - 1, x_max + 1)
    YY = -(w[0] / w[1]) * XX - b / w[1]
    plt.plot(XX, YY, '-c', label='Hyperplane')
    plt.show()


# 优化目标： MIN L(w,b) = (-1)*yi * (w * xi + b) 最小
def loss_fun(data, target, w, b):
    loss = 0.0
    # 划分错误的是
    loss_num = 0
    for i in range(len(target)):
        loss += (-1) * target[i] * (np.dot(w, data[i].T) + b)
        if target[i] * (np.dot(w, data[i].T) + b) <= 0:
            loss_num+=1

    return loss,loss_num


# 初始化 w , b
w = np.array((0.0, 0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.01

while (num_epochs <= 40):
    # 随机打乱数据
    data, target = sklearn.utils.shuffle(data, target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i] * (np.dot(w, data[i].T) + b) <= 0:
            w = w + lr * target[i] * data[i]
            b = b + lr * target[i]
        if ((i + 1) % epoch == 0):
            loss,loss_num = loss_fun(data, target, w, b)
            print("第{}轮训练，after第{}条数据    w:{},b:{}\n损失函数值为{}    划分错误的个数是{}：".format(num_epochs, (i + 1), w, b,loss,loss_num))
            show_data_line(data, target, w, b)

    num_epochs += 1
# Out:
# 生成的数据如下：
# 第1轮训练，after第20条数据    w:[-0.03907175 -0.0040723 ],b:-0.02
# 损失函数值为-1.9297596606072571    划分错误的个数是17：
# 第1轮训练，after第40条数据    w:[-0.03184757  0.04479313],b:-0.02
# 损失函数值为-1.8790072735287737    划分错误的个数是17：
# 第1轮训练，after第60条数据    w:[-0.030611    0.03504757],b:-0.04
# 损失函数值为-1.755120371308187    划分错误的个数是3：
# 第2轮训练，after第20条数据    w:[-0.04427815  0.02847126],b:-0.04
# 损失函数值为-2.397371293245146    划分错误的个数是6：
# 第2轮训练，after第40条数据    w:[-0.04140499  0.03374601],b:-0.05
# 损失函数值为-2.287113825751273    划分错误的个数是1：
# 第2轮训练，after第60条数据    w:[-0.04140499  0.03374601],b:-0.05
# 损失函数值为-2.287113825751273    划分错误的个数是1：
# 第3轮训练，after第20条数据    w:[-0.0317153  0.0471632],b:-0.05
# 损失函数值为-1.887463125816428    划分错误的个数是8：
# 第3轮训练，after第40条数据    w:[-0.04807189  0.04856763],b:-0.05
# 损失函数值为-2.7150960615164506    划分错误的个数是3：
# 第3轮训练，after第60条数据    w:[-0.04807189  0.04856763],b:-0.05
# 损失函数值为-2.7150960615164506    划分错误的个数是3：
# 第4轮训练，after第20条数据    w:[-0.04807189  0.04856763],b:-0.05
# 损失函数值为-2.7150960615164506    划分错误的个数是3：
# 第4轮训练，after第40条数据    w:[-0.0492073   0.03288436],b:-0.060000000000000005
# 损失函数值为-2.67216287513168    划分错误的个数是8：
# 第4轮训练，after第60条数据    w:[-0.03623415  0.03955505],b:-0.07
# 损失函数值为-2.065249353497648    划分错误的个数是7：
# 第5轮训练，after第20条数据    w:[-0.05258502  0.03985273],b:-0.060000000000000005
# 损失函数值为-2.8855556184690623    划分错误的个数是3：
# 第5轮训练，after第40条数据    w:[-0.04778359  0.03419975],b:-0.07
# 损失函数值为-2.609269250236354    划分错误的个数是11：
# 第5轮训练，after第60条数据    w:[-0.06914005  0.05097131],b:-0.05
# 损失函数值为-3.7849138144781884    划分错误的个数是3：
# 第6轮训练，after第20条数据    w:[-0.06560617  0.0590894 ],b:-0.05
# 损失函数值为-3.6596725170328566    划分错误的个数是4：
# 第6轮训练，after第40条数据    w:[-0.06784969  0.03326637],b:-0.07
# 损失函数值为-3.6077032528263073    划分错误的个数是10：
# 第6轮训练，after第60条数据    w:[-0.05766363  0.06623809],b:-0.060000000000000005
# 损失函数值为-3.3075975689024837    划分错误的个数是4：
# 第7轮训练，after第20条数据    w:[-0.06663459  0.04317715],b:-0.07
# 损失函数值为-3.6099281395134692    划分错误的个数是5：
# 第7轮训练，after第40条数据    w:[-0.05563402  0.04854087],b:-0.08
# 损失函数值为-3.0934343426541933    划分错误的个数是1：
# 第7轮训练，after第60条数据    w:[-0.05563402  0.04854087],b:-0.08
# 损失函数值为-3.0934343426541933    划分错误的个数是1：
# 第8轮训练，after第20条数据    w:[-0.05563402  0.04854087],b:-0.08
# 损失函数值为-3.0934343426541933    划分错误的个数是1：
# 第8轮训练，after第40条数据    w:[-0.04238993  0.07972762],b:-0.07
# 损失函数值为-2.6289098100014656    划分错误的个数是15：
# 第8轮训练，after第60条数据    w:[-0.06090303  0.04418513],b:-0.09
# 损失函数值为-3.329457172159953    划分错误的个数是11：
# 第9轮训练，after第20条数据    w:[-0.05318591  0.05629535],b:-0.09
# 损失函数值为-3.0202261969998667    划分错误的个数是2：
# 第9轮训练，after第40条数据    w:[-0.07908285  0.06801341],b:-0.07
# 损失函数值为-4.390989828367711    划分错误的个数是3：
# 第9轮训练，after第60条数据    w:[-0.0747118  0.0617552],b:-0.08
# 损失函数值为-4.132395619762854    划分错误的个数是2：
# 第10轮训练，after第20条数据    w:[-0.0747118  0.0617552],b:-0.08
# 损失函数值为-4.132395619762853    划分错误的个数是2：
# 第10轮训练，after第40条数据    w:[-0.0747118  0.0617552],b:-0.08
# 损失函数值为-4.132395619762853    划分错误的个数是2：
# 第10轮训练，after第60条数据    w:[-0.06707568  0.07487678],b:-0.08
# 损失函数值为-3.8336519856224633    划分错误的个数是3：
# 第11轮训练，after第20条数据    w:[-0.06707568  0.07487678],b:-0.08
# 损失函数值为-3.833651985622464    划分错误的个数是3：
# 第11轮训练，after第40条数据    w:[-0.07094697  0.07622245],b:-0.08
# 损失函数值为-4.0359822855450345    划分错误的个数是3：
# 第11轮训练，after第60条数据    w:[-0.05874036  0.07734189],b:-0.09
# 损失函数值为-3.4321243199444216    划分错误的个数是6：
# 第12轮训练，after第20条数据    w:[-0.09373707  0.04725115],b:-0.09
# 损失函数值为-4.992407565857805    划分错误的个数是10：
# 第12轮训练，after第40条数据    w:[-0.06842245  0.10349767],b:-0.08
# 损失函数值为-4.083124349192197    划分错误的个数是12：
# 第12轮训练，after第60条数据    w:[-0.08496297  0.06926216],b:-0.09999999999999999
# 损失函数值为-4.693251986575927    划分错误的个数是1：
# 第13轮训练，after第20条数据    w:[-0.08496297  0.06926216],b:-0.09999999999999999
# 损失函数值为-4.693251986575926    划分错误的个数是1：
# 第13轮训练，after第40条数据    w:[-0.08496297  0.06926216],b:-0.09999999999999999
# 损失函数值为-4.693251986575926    划分错误的个数是1：
# 第13轮训练，after第60条数据    w:[-0.07732685  0.08238374],b:-0.09999999999999999
# 损失函数值为-4.394508352435536    划分错误的个数是3：
# 第14轮训练，after第20条数据    w:[-0.07732685  0.08238374],b:-0.09999999999999999
# 损失函数值为-4.394508352435536    划分错误的个数是3：
# 第14轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第14轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第15轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第15轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第15轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第16轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第16轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第16轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第17轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第17轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第17轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第18轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第18轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第18轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第19轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第19轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第19轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第20轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第20轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第20轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第21轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第21轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第21轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第22轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第22轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第22轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第23轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第23轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第23轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第24轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第24轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第24轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第25轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第25轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第25轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第26轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第26轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第26轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第27轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第27轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第27轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第28轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第28轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第28轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第29轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第29轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第29轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第30轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276008    划分错误的个数是0：
# 第30轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276008    划分错误的个数是0：
# 第30轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276008    划分错误的个数是0：
# 第31轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第31轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第31轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第32轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第32轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第32轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第33轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第33轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第33轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第34轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第34轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第34轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第35轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第35轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第35轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276009    划分错误的个数是0：
# 第36轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第36轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第36轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276011    划分错误的个数是0：
# 第37轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第37轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第37轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第38轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第38轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第38轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第39轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第39轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第39轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.261155441276012    划分错误的个数是0：
# 第40轮训练，after第20条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第40轮训练，after第40条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
# 第40轮训练，after第60条数据    w:[-0.07648968  0.06800744],b:-0.10999999999999999
# 损失函数值为-4.26115544127601    划分错误的个数是0：
