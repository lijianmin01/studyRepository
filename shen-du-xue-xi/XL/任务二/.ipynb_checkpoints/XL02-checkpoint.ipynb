# %%
# 调用numpy库生成二分类数据 40 条  没有冗余数据 ，二维数据
# def create_data():
#     import numpy as np
#     np.random.seed(0)
#     data=np.r_[np.random.randn(20,2)-[2,2],np.random.randn(20,2)+[2,2]]
#     target=20*[-1]+20*[1]

#     return data,target

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=100,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=0)
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

if __name__ == '__main__':
    data,target = create_data()
    show_data(data,target)
# Out:
# [-0.6054158   1.29670808] 1

# %%
import sklearn 

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1

# 分类效果展示
def show_data_line(data,target,w,b):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min,y_min] = np.min(data,axis=0)
    [x_max,y_max] = np.max(data,axis=0)


    XX=np.linspace(x_min-1,x_max+1)
    YY=-(w[0]/w[1])*XX-b/w[1]
    plt.plot(XX,YY,'-c',label='Hyperplane')
    plt.show()

# 初始化 w , b 
w = np.array((0.0,0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.01

while (num_epochs<=10):
    # 随机打乱数据
    data,target = sklearn.utils.shuffle(data,target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i]*(w[0]*data[i][0]+w[1]*data[i][1]+b)<=0:
            # w = w+lr*target[i]*data[i]
            w[0] = w[0]+lr*target[i]*data[i][0]
            w[1] = w[1]+lr*target[i]*data[i][1]
            b = b+lr*target[i]
        if ((i+1)%epoch == 0):
            print("第{}轮训练，第{}条数据，分类效果如图,w:{},b:{}：".format(num_epochs,(i+1),w,b))
            show_data_line(data,target,w,b)
    num_epochs+=1
# Out:
# [-0.6054158   1.29670808] 1
# 第1轮训练，第20条数据，分类效果如图,w:[-0.00073553  0.01394118],b:-0.01：
# 第1轮训练，第40条数据，分类效果如图,w:[-0.00623814  0.03695582],b:-0.01：
# 第1轮训练，第60条数据，分类效果如图,w:[-0.00640737  0.02540851],b:-0.02：
# 第1轮训练，第80条数据，分类效果如图,w:[0.00542878 0.03461623],b:-0.01：
# 第1轮训练，第100条数据，分类效果如图,w:[0.01623511 0.03379819],b:-0.019999999999999997：
# 第2轮训练，第20条数据，分类效果如图,w:[0.01623511 0.03379819],b:-0.019999999999999997：
# 第2轮训练，第40条数据，分类效果如图,w:[0.01663394 0.03711613],b:-0.009999999999999997：
# 第2轮训练，第60条数据，分类效果如图,w:[0.01997883 0.0362935 ],b:-0.009999999999999997：
# 第2轮训练，第80条数据，分类效果如图,w:[0.01000034 0.03251953],b:-0.009999999999999997：
# 第2轮训练，第100条数据，分类效果如图,w:[-0.00354866  0.03298831],b:-0.019999999999999997：
# 第3轮训练，第20条数据，分类效果如图,w:[0.00097986 0.02909693],b:-0.019999999999999997：
# 第3轮训练，第40条数据，分类效果如图,w:[-0.00106951  0.01549961],b:-0.03：
# 第3轮训练，第60条数据，分类效果如图,w:[0.01581131 0.0353456 ],b:-0.009999999999999997：
# 第3轮训练，第80条数据，分类效果如图,w:[0.0117949  0.03533335],b:-0.009999999999999997：
# 第3轮训练，第100条数据，分类效果如图,w:[-0.00175409  0.03580213],b:-0.019999999999999997：
# 第4轮训练，第20条数据，分类效果如图,w:[-0.00175409  0.03580213],b:-0.019999999999999997：
# 第4轮训练，第40条数据，分类效果如图,w:[0.00224847 0.03356099],b:-0.019999999999999997：
# 第4轮训练，第60条数据，分类效果如图,w:[0.00224847 0.03356099],b:-0.019999999999999997：
# 第4轮训练，第80条数据，分类效果如图,w:[0.00968073 0.04335565],b:-0.019999999999999997：
# 第4轮训练，第100条数据，分类效果如图,w:[0.00763136 0.02975833],b:-0.03：
# 第5轮训练，第20条数据，分类效果如图,w:[0.01432717 0.0339504 ],b:-0.03：
# 第5轮训练，第40条数据，分类效果如图,w:[0.01249821 0.04136431],b:-0.019999999999999997：
# 第5轮训练，第60条数据，分类效果如图,w:[-0.00346922  0.04108919],b:-0.03：
# 第5轮训练，第80条数据，分类效果如图,w:[0.00251548 0.04417793],b:-0.019999999999999997：
# 第5轮训练，第100条数据，分类效果如图,w:[0.01560795 0.04453109],b:-0.019999999999999997：
# 第6轮训练，第20条数据，分类效果如图,w:[0.01355858 0.03093376],b:-0.03：
# 第6轮训练，第40条数据，分类效果如图,w:[0.01671463 0.03619943],b:-0.03：
# 第6轮训练，第60条数据，分类效果如图,w:[0.02050223 0.03667947],b:-0.03：
# 第6轮训练，第80条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第6轮训练，第100条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第20条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第40条数据，分类效果如图,w:[0.0091964  0.04957713],b:-0.019999999999999997：
# 第7轮训练，第60条数据，分类效果如图,w:[0.00700896 0.04215097],b:-0.03：
# 第7轮训练，第80条数据，分类效果如图,w:[0.00700896 0.04215097],b:-0.03：
# 第7轮训练，第100条数据，分类效果如图,w:[-0.00044345  0.04781393],b:-0.019999999999999997：
# 第8轮训练，第20条数据，分类效果如图,w:[-0.00044345  0.04781393],b:-0.019999999999999997：
# 第8轮训练，第40条数据，分类效果如图,w:[0.0037238  0.03110513],b:-0.03：
# 第8轮训练，第60条数据，分类效果如图,w:[0.00330147 0.03894014],b:-0.03：
# 第8轮训练，第80条数据，分类效果如图,w:[0.0014725  0.04635406],b:-0.019999999999999997：
# 第8轮训练，第100条数据，分类效果如图,w:[0.0014725  0.04635406],b:-0.019999999999999997：
# 第9轮训练，第20条数据，分类效果如图,w:[-0.00134925  0.04222054],b:-0.03：
# 第9轮训练，第40条数据，分类效果如图,w:[-0.00949877  0.03103266],b:-0.04：
# 第9轮训练，第60条数据，分类效果如图,w:[0.00630061 0.03732273],b:-0.03：
# 第9轮训练，第80条数据，分类效果如图,w:[0.00164747 0.04590739],b:-0.019999999999999997：
# 第9轮训练，第100条数据，分类效果如图,w:[0.00164747 0.04590739],b:-0.019999999999999997：
# 第10轮训练，第20条数据，分类效果如图,w:[-0.00458247  0.05052995],b:-0.03：
# 第10轮训练，第40条数据，分类效果如图,w:[-0.00458247  0.05052995],b:-0.03：
# 第10轮训练，第60条数据，分类效果如图,w:[-0.012732    0.03934208],b:-0.04：
# 第10轮训练，第80条数据，分类效果如图,w:[0.00703789 0.0472006 ],b:-0.03：
# 第10轮训练，第100条数据，分类效果如图,w:[0.00703789 0.0472006 ],b:-0.03：

# %%
import numpy as np
a = np.array([1,2])
b = np.array([3,4])

print(a+b)
# Out:
# [4 6]

# %%
import sklearn 
import matplotlib.pyplot as plt
import numpy as np

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=60,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=18)
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1

# 分类效果展示
def show_data_line(data,target,w,b):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min,y_min] = np.min(data,axis=0)
    [x_max,y_max] = np.max(data,axis=0)


    XX=np.linspace(x_min-1,x_max+1)
    YY=-(w[0]/w[1])*XX-b/w[1]
    plt.plot(XX,YY,'-c',label='Hyperplane')
    plt.show()

# 优化目标： MIN L(w,b) = (-1)*yi * (w * xi + b) 最小
def loss_fun(data,target,w,b):
    loss = 0.0
    for i in range(len(target)):
        loss+= (-1)*target[i]*(np.dot(w,data[i].T)+b)
    
    return loss

# 初始化 w , b 
w = np.array((0.0,0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.005

while (num_epochs<=10):
    # 随机打乱数据
    data,target = sklearn.utils.shuffle(data,target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i]*(np.dot(w,data[i].T)+b)<=0:
            w = w+lr*target[i]*data[i]
            b = b+lr*target[i]
        if ((i+1)%epoch == 0):
            print("第{}轮训练，after第{}条数据，分类效果如图,w:{},b:{},损失函数值为{}：".format(num_epochs,(i+1),w,b,loss_fun(data,target,w,b)))
            show_data_line(data,target,w,b)
    num_epochs+=1
# Out:
# [1.32083284 1.45861278] 0
# 第1轮训练，after第20条数据，分类效果如图,w:[-0.01346245  0.00869865],b:-0.005,损失函数值为-0.7291713048939578：
# 第1轮训练，after第40条数据，分类效果如图,w:[-0.02265332  0.01322716],b:-0.005,损失函数值为-1.2180103394062338：
# 第1轮训练，after第60条数据，分类效果如图,w:[-0.02037561  0.01406459],b:-0.01,损失函数值为-1.109330345812528：
# 第2轮训练，after第20条数据，分类效果如图,w:[-0.01754476  0.01804637],b:-0.015,损失函数值为-0.9929665146523563：
# 第2轮训练，after第40条数据，分类效果如图,w:[-0.01838402  0.03091635],b:-0.009999999999999998,损失函数值为-1.1168417948866818：
# 第2轮训练，after第60条数据，分类效果如图,w:[-0.01895172  0.02307471],b:-0.015,损失函数值为-1.0953752016942973：
# 第3轮训练，after第20条数据，分类效果如图,w:[-0.020792    0.02367571],b:-0.02,损失函数值为-1.1913102176678403：
# 第3轮训练，after第40条数据，分类效果如图,w:[-0.020792    0.02367571],b:-0.02,损失函数值为-1.1913102176678403：
# 第3轮训练，after第60条数据，分类效果如图,w:[-0.02915609  0.01921004],b:-0.02,损失函数值为-1.5815524128118061：
# 第4轮训练，after第20条数据，分类效果如图,w:[-0.02915609  0.01921004],b:-0.02,损失函数值为-1.581552412811806：
# 第4轮训练，after第40条数据，分类效果如图,w:[-0.02266837  0.0310753 ],b:-0.02,损失函数值为-1.3322983169328348：
# 第4轮训练，after第60条数据，分类效果如图,w:[-0.02715385  0.01954483],b:-0.025,损失函数值为-1.4834636022383276：
# 第5轮训练，after第20条数据，分类效果如图,w:[-0.02501729  0.02360774],b:-0.025,损失函数值为-1.4023666212174568：
# 第5轮训练，after第40条数据，分类效果如图,w:[-0.02337042  0.02474716],b:-0.030000000000000002,损失函数值为-1.327183808499076：
# 第5轮训练，after第60条数据，分类效果如图,w:[-0.01951186  0.03080227],b:-0.030000000000000002,损失函数值为-1.1725683209190336：
# 第6轮训练，after第20条数据，分类效果如图,w:[-0.03196285  0.02805112],b:-0.030000000000000002,损失函数值为-1.7782791655651926：
# 第6轮训练，after第40条数据，分类效果如图,w:[-0.03423775  0.02951896],b:-0.030000000000000002,损失函数值为-1.9014822981515194：
# 第6轮训练，after第60条数据，分类效果如图,w:[-0.03179018  0.03072512],b:-0.035,损失函数值为-1.7866462450080576：
# 第7轮训练，after第20条数据，分类效果如图,w:[-0.03235789  0.02288348],b:-0.04,损失函数值为-1.7651796518156735：
# 第7轮训练，after第40条数据，分类效果如图,w:[-0.03089949  0.03205318],b:-0.04,损失函数值为-1.750512247640011：
# 第7轮训练，after第60条数据，分类效果如图,w:[-0.03718478  0.02820577],b:-0.04,损失函数值为-2.0406367538725196：
# 第8轮训练，after第20条数据，分类效果如图,w:[-0.0381466   0.03032159],b:-0.04,损失函数值为-2.1022378877130703：
# 第8轮训练，after第40条数据，分类效果如图,w:[-0.03110597  0.03872682],b:-0.04,损失函数值为-1.8032991658069428：
# 第8轮训练，after第60条数据，分类效果如图,w:[-0.03559145  0.02719635],b:-0.045,损失函数值为-1.9544644511124343：
# 第9轮训练，after第20条数据，分类效果如图,w:[-0.02933903  0.04278586],b:-0.04,损失函数值为-1.7406785170842767：
# 第9轮训练，after第40条数据，分类效果如图,w:[-0.03472942  0.03435298],b:-0.045,损失函数值为-1.9568418618413521：
# 第9轮训练，after第60条数据，分类效果如图,w:[-0.03147906  0.03307213],b:-0.049999999999999996,损失函数值为-1.7860034515787735：
# 第10轮训练，after第20条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：
# 第10轮训练，after第40条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：
# 第10轮训练，after第60条数据，分类效果如图,w:[-0.03286029  0.03356703],b:-0.049999999999999996,损失函数值为-1.8582862169260266：

# %%
1
# Out:
# 1

# %%
import sklearn 
import matplotlib.pyplot as plt

def create_data():
    from sklearn.datasets import make_classification
    data,target = make_classification(n_samples=60,        # 样本个数
                               n_features=2,          # 特征个数
                               n_informative=2,        # 有效特征个数
                               n_redundant=0,          # 冗余特征个数（有效特征的随机组合）
                               n_repeated=0,           # 重复特征个数（有效特征和冗余特征的随机组合）
                               n_classes=2,            # 样本类别
                               n_clusters_per_class=1, # 簇的个数
                               random_state=18)
    # random_state 取值为线性可分为  3  8 18
    return data,target


# 数据的可视化
def show_data(data,target):
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if(target[i]==data_label[0]):
            plt.scatter(data[i][0],data[i][1],c='r')
        else:
            plt.scatter(data[i][0],data[i][1],c='g')
    plt.show()

data,target = create_data()
print(data[0],target[0])
show_data(data,target)
for i in range(len(target)):
    if target[i]==0:
        target[i]=-1
# Out:
# [1.32083284 1.45861278] 0

# %%
import sklearn
import numpy as np

def create_data():
    """# 为了是数值取值为线性可分为 random_state 取值为 3  8 18  （后面的没有测试）  
        18 最能体现划分过程
    """
    from sklearn.datasets import make_classification
    data, target = make_classification(n_samples=60,  # 样本个数
                                       n_features=2,  # 特征个数
                                       n_informative=2,  # 有效特征个数
                                       n_redundant=0,  # 冗余特征个数（有效特征的随机组合）
                                       n_repeated=0,  # 重复特征个数（有效特征和冗余特征的随机组合）
                                       n_classes=2,  # 样本类别
                                       n_clusters_per_class=1,  # 簇的个数
                                       random_state=18)
    return data, target


# 数据的可视化
def show_data(data, target):
    import matplotlib.pyplot as plt
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if (target[i] == data_label[0]):
            plt.scatter(data[i][0], data[i][1], c='r')
        else:
            plt.scatter(data[i][0], data[i][1], c='g')
    plt.show()


data, target = create_data()
print("生成的数据如下：")
show_data(data, target)
for i in range(len(target)):
    if target[i] == 0:
        target[i] = -1


# 分类效果展示
def show_data_line(data, target, w, b):
    import matplotlib.pyplot as plt
    import numpy as np
    data_label = list(set(target))
    plt.figure()
    for i in range(len(target)):
        if (target[i] == data_label[0]):
            plt.scatter(data[i][0], data[i][1], c='r')
        else:
            plt.scatter(data[i][0], data[i][1], c='g')

    # 为了更客观的看出图像的变化，这里我们先找出原来的图像的坐标轴的横纵坐标的最大，最小
    # x_min,x_max,y_min,y_max = 0.0,0.0,0.0,0.0

    [x_min, y_min] = np.min(data, axis=0)
    [x_max, y_max] = np.max(data, axis=0)

    XX = np.linspace(x_min - 1, x_max + 1)
    YY = -(w[0] / w[1]) * XX - b / w[1]
    plt.plot(XX, YY, '-c', label='Hyperplane')
    plt.show()


# 优化目标： MIN L(w,b) = (-1)*yi * (w * xi + b) 最小
def loss_fun(data, target, w, b):
    loss = 0.0
    # 划分错误的是
    loss_num = 0
    for i in range(len(target)):
        loss += (-1) * target[i] * (np.dot(w, data[i].T) + b)
        if target[i] * (np.dot(w, data[i].T) + b) <= 0:
            loss_num+=1

    return loss,loss_num


# 初始化 w , b
w = np.array((0.0, 0.0))
b = 0.0

# 所有数据训练10轮
num_epochs = 1

# 每10条数据为一个周期
epoch = 20

# 学习率 0.01
lr = 0.01

while (num_epochs <= 20):
    # 随机打乱数据
    data, target = sklearn.utils.shuffle(data, target)
    # 记录已经训练过的数据的条数
    tarin_data_num = 0
    for i in range(len(target)):
        # 分类错误，感知机
        if target[i] * (np.dot(w, data[i].T) + b) <= 0:
            w = w + lr * target[i] * data[i]
            b = b + lr * target[i]
        if ((i + 1) % epoch == 0):
            loss,loss_num = loss_fun(data, target, w, b)
            print("第{}轮训练，after第{}条数据，分类效果如图,w:{},b:{},损失函数值为{},划分错误的个数是{}：".format(num_epochs, (i + 1), w, b,loss,loss_num))
            show_data_line(data, target, w, b)

    num_epochs += 1
# Out:
# 生成的数据如下：
# 第1轮训练，after第20条数据，分类效果如图,w:[-0.02707311  0.0162753 ],b:-0.01,损失函数值为-1.4586240548759861,划分错误的个数是6：
# 第1轮训练，after第40条数据，分类效果如图,w:[-0.02664624  0.04610103],b:0.0,损失函数值为-1.6269843956290173,划分错误的个数是22：
# 第1轮训练，after第60条数据，分类效果如图,w:[-0.03032785  0.03248703],b:-0.03,损失函数值为-1.7246598206879606,划分错误的个数是3：
# 第2轮训练，after第20条数据，分类效果如图,w:[-0.00995208  0.06066851],b:-0.03,损失函数值为-0.8840548251870013,划分错误的个数是31：
# 第2轮训练，after第40条数据，分类效果如图,w:[-0.05280585  0.03427644],b:-0.03,损失函数值为-2.861137078635699,划分错误的个数是3：
# 第2轮训练，after第60条数据，分类效果如图,w:[-0.05735565  0.03721212],b:-0.03,损失函数值为-3.107543343808355,划分错误的个数是4：
# 第3轮训练，after第20条数据，分类效果如图,w:[-0.05157964  0.05090086],b:-0.03,损失函数值为-2.90551221148418,划分错误的个数是8：
# 第3轮训练，after第40条数据，分类效果如图,w:[-0.04507893  0.04833916],b:-0.04,损失函数值为-2.5638353909590204,划分错误的个数是4：
# 第3轮训练，after第60条数据，分类效果如图,w:[-0.04618704  0.03819941],b:-0.05,损失函数值为-2.554799313137241,划分错误的个数是2：
# 第4轮训练，after第20条数据，分类效果如图,w:[-0.03257548  0.0592658 ],b:-0.05,损失函数值为-2.007504423817312,划分错误的个数是16：
# 第4轮训练，after第40条数据，分类效果如图,w:[-0.04819039  0.0417814 ],b:-0.060000000000000005,损失函数值为-2.6778591088588244,划分错误的个数是2：
# 第4轮训练，after第60条数据，分类效果如图,w:[-0.04733785  0.04930757],b:-0.060000000000000005,损失函数值为-2.683061944474743,划分错误的个数是3：
# 第5轮训练，after第20条数据，分类效果如图,w:[-0.04733785  0.04930757],b:-0.060000000000000005,损失函数值为-2.683061944474743,划分错误的个数是3：
# 第5轮训练，after第40条数据，分类效果如图,w:[-0.06901052  0.05212316],b:-0.05,损失函数值为-3.7857577037401016,划分错误的个数是3：
# 第5轮训练，after第60条数据，分类效果如图,w:[-0.0658728  0.0445657],b:-0.060000000000000005,损失函数值为-3.5806305553135918,划分错误的个数是4：
# 第6轮训练，after第20条数据，分类效果如图,w:[-0.05253079  0.06136842],b:-0.060000000000000005,损失函数值为-3.019705776097747,划分错误的个数是3：
# 第6轮训练，after第40条数据，分类效果如图,w:[-0.05366619  0.04568515],b:-0.07,损失函数值为-2.9767725897129775,划分错误的个数是1：
# 第6轮训练，after第60条数据，分类效果如图,w:[-0.05366619  0.04568515],b:-0.07,损失函数值为-2.9767725897129775,划分错误的个数是1：
# 第7轮训练，after第20条数据，分类效果如图,w:[-0.05366619  0.04568515],b:-0.07,损失函数值为-2.9767725897129775,划分错误的个数是1：
# 第7轮训练，after第40条数据，分类效果如图,w:[-0.05366619  0.04568515],b:-0.07,损失函数值为-2.9767725897129775,划分错误的个数是1：
# 第7轮训练，after第60条数据，分类效果如图,w:[-0.05725884  0.04716241],b:-0.07,损失函数值为-3.1659930436562136,划分错误的个数是1：
# 第8轮训练，after第20条数据，分类效果如图,w:[-0.05725884  0.04716241],b:-0.07,损失函数值为-3.1659930436562145,划分错误的个数是1：
# 第8轮训练，after第40条数据，分类效果如图,w:[-0.0564063   0.05468858],b:-0.07,损失函数值为-3.1711958792721338,划分错误的个数是3：
# 第8轮训练，after第60条数据，分类效果如图,w:[-0.04884742  0.07312773],b:-0.07,损失函数值为-2.9101444254072932,划分错误的个数是7：
# 第9轮训练，after第20条数据，分类效果如图,w:[-0.05781838  0.05006679],b:-0.08,损失函数值为-3.212474996018277,划分错误的个数是1：
# 第9轮训练，after第40条数据，分类效果如图,w:[-0.05781838  0.05006679],b:-0.08,损失函数值为-3.212474996018277,划分错误的个数是1：
# 第9轮训练，after第60条数据，分类效果如图,w:[-0.0456824   0.07111379],b:-0.08,损失函数值为-2.7389143855437705,划分错误的个数是9：
# 第10轮训练，after第20条数据，分类效果如图,w:[-0.08067911  0.04102305],b:-0.08,损失函数值为-4.299197631457155,划分错误的个数是10：
# 第10轮训练，after第40条数据，分类效果如图,w:[-0.07625795  0.06701966],b:-0.07,损失函数值为-4.243273326018825,划分错误的个数是3：
# 第10轮训练，after第60条数据，分类效果如图,w:[-0.07542078  0.05264336],b:-0.08,损失函数值为-4.109920414859298,划分错误的个数是5：
# 第11轮训练，after第20条数据，分类效果如图,w:[-0.07542078  0.05264336],b:-0.08,损失函数值为-4.109920414859297,划分错误的个数是5：
# 第11轮训练，after第40条数据，分类效果如图,w:[-0.06207877  0.06944608],b:-0.08,损失函数值为-3.5489956356434536,划分错误的个数是3：
# 第11轮训练，after第60条数据，分类效果如图,w:[-0.06207877  0.06944608],b:-0.08,损失函数值为-3.5489956356434536,划分错误的个数是3：
# 第12轮训练，after第20条数据，分类效果如图,w:[-0.06207877  0.06944608],b:-0.08,损失函数值为-3.5489956356434536,划分错误的个数是3：
# 第12轮训练，after第40条数据，分类效果如图,w:[-0.06207877  0.06944608],b:-0.08,损失函数值为-3.5489956356434536,划分错误的个数是3：
# 第12轮训练，after第60条数据，分类效果如图,w:[-0.06341361  0.05950673],b:-0.09,损失函数值为-3.55258257211405,划分错误的个数是1：
# 第13轮训练，after第20条数据，分类效果如图,w:[-0.04933235  0.07631717],b:-0.09,损失函数值为-2.9547051283017955,划分错误的个数是9：
# 第13轮训练，after第40条数据，分类效果如图,w:[-0.07779129  0.07616945],b:-0.08,损失函数值为-4.378225035473909,划分错误的个数是3：
# 第13轮训练，after第60条数据，分类效果如图,w:[-0.07779129  0.07616945],b:-0.08,损失函数值为-4.378225035473909,划分错误的个数是3：
# 第14轮训练，after第20条数据，分类效果如图,w:[-0.07779129  0.07616945],b:-0.08,损失函数值为-4.378225035473909,划分错误的个数是3：
# 第14轮训练，after第40条数据，分类效果如图,w:[-0.069237    0.07390336],b:-0.09,损失函数值为-3.9356411491542964,划分错误的个数是3：
# 第14轮训练，after第60条数据，分类效果如图,w:[-0.05866935  0.09340021],b:-0.09,损失函数值为-3.53071963542385,划分错误的个数是9：
# 第15轮训练，after第20条数据，分类效果如图,w:[-0.05783219  0.07902391],b:-0.09999999999999999,损失函数值为-3.397366724264324,划分错误的个数是9：
# 第15轮训练，after第40条数据，分类效果如图,w:[-0.09206736  0.06342754],b:-0.09,损失函数值为-5.011734077333731,划分错误的个数是3：
# 第15轮训练，after第60条数据，分类效果如图,w:[-0.07956252  0.09460657],b:-0.08,损失函数值为-4.584162209277412,划分错误的个数是4：
# 第16轮训练，after第20条数据，分类效果如图,w:[-0.08966889  0.05586236],b:-0.09999999999999999,损失函数值为-4.84355959350363,划分错误的个数是8：
# 第16轮训练，after第40条数据，分类效果如图,w:[-0.07558763  0.0726728 ],b:-0.09999999999999999,损失函数值为-4.245682149691375,划分错误的个数是2：
# 第16轮训练，after第60条数据，分类效果如图,w:[-0.07558763  0.0726728 ],b:-0.09999999999999999,损失函数值为-4.245682149691375,划分错误的个数是2：
# 第17轮训练，after第20条数据，分类效果如图,w:[-0.06347894  0.08817627],b:-0.09999999999999999,损失函数值为-3.7382244306538808,划分错误的个数是7：
# 第17轮训练，after第40条数据，分类效果如图,w:[-0.09533766  0.05802015],b:-0.09999999999999999,损失函数值为-5.141025873843062,划分错误的个数是8：
# 第17轮训练，after第60条数据，分类效果如图,w:[-0.07579906  0.10057793],b:-0.09,损失函数值为-4.433773789501627,划分错误的个数是5：
# 第18轮训练，after第20条数据，分类效果如图,w:[-0.08393285  0.0631407 ],b:-0.10999999999999999,损失函数值为-4.602751448953086,划分错误的个数是5：
# 第18轮训练，after第40条数据，分类效果如图,w:[-0.07342734  0.09070991],b:-0.10999999999999999,损失函数值为-4.252290120616527,划分错误的个数是5：
# 第18轮训练，after第60条数据，分类效果如图,w:[-0.09287915  0.10611684],b:-0.09,损失函数值为-5.323919942312508,划分错误的个数是4：
# 第19轮训练，after第20条数据，分类效果如图,w:[-0.10101294  0.06867961],b:-0.10999999999999999,损失函数值为-5.492897601763966,划分错误的个数是5：
# 第19轮训练，after第40条数据，分类效果如图,w:[-0.08626597  0.10542928],b:-0.09999999999999999,损失函数值为-4.9885358988288075,划分错误的个数是3：
# 第19轮训练，after第60条数据，分类效果如图,w:[-0.08740137  0.089746  ],b:-0.10999999999999999,损失函数值为-4.9456027124440345,划分错误的个数是3：
# 第20轮训练，after第20条数据，分类效果如图,w:[-0.10952786  0.0896531 ],b:-0.09999999999999999,损失函数值为-6.0525123464759485,划分错误的个数是3：
# 第20轮训练，after第40条数据，分类效果如图,w:[-0.1086907  0.0752768],b:-0.10999999999999999,损失函数值为-5.919159435316422,划分错误的个数是4：
# 第20轮训练，after第60条数据，分类效果如图,w:[-0.1086907  0.0752768],b:-0.10999999999999999,损失函数值为-5.919159435316422,划分错误的个数是4：
